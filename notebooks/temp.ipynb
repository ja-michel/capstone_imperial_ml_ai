# %%
import os, pandas, pathlib
import numpy as np
import pandas as pd

# %%
func = ["f1", "f2"]
dfs = []

for f in func:
    loc = pathlib.WindowsPath(f"C:\\Users\\Arturo\\repos\\capstone_imperial_ml_ai\\data\\initial_data\\{f}")
    inputs = np.load(loc.as_posix() + "/initial_inputs.npy")
    output = np.load(loc.as_posix() + "/initial_outputs.npy")

    df = pd.DataFrame(inputs, columns=['x1', 'x2'])
    df['func'] = f
    df['target'] = output
    dfs.append(df)

all_data = pd.concat(dfs)
